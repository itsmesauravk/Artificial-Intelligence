# %%
import pandas as pd

# %%
df0 = pd.read_csv('CSVFiles/LifeExpentancy.csv')

# %%
df0.head()
# Out:
#        Country  Year      Status  Lifeexpectancy  AdultMortality  \
# 0  Afghanistan  2015  Developing            65.0           263.0
# 1  Afghanistan  2014  Developing            59.9           271.0
# 2  Afghanistan  2013  Developing            59.9           268.0
# 3  Afghanistan  2012  Developing            59.5           272.0
# 4  Afghanistan  2011  Developing            59.2           275.0
#
#    infantdeaths  Alcohol  percentageexpenditure  HepatitisB  Measles  ...  \
# 0            62     0.01              71.279624        65.0     1154  ...
# 1            64     0.01              73.523582        62.0      492  ...
# 2            66     0.01              73.219243        64.0      430  ...
# 3            69     0.01              78.184215        67.0     2787  ...
# 4            71     0.01               7.097109        68.0     3013  ...
#
#    Polio  Totalexpenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
print(df0.shape)
print(df0.columns)
# Out:
# (2938, 22)
# Index(['Country', 'Year', 'Status', 'Lifeexpectancy', 'AdultMortality',
#        'infantdeaths', 'Alcohol', 'percentageexpenditure', 'HepatitisB',
#        'Measles', 'BMI', 'under-fivedeaths', 'Polio', 'Totalexpenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness1-19years',
#        'thinness5-9years', 'Incomecompositionofresources', 'Schooling'],
#       dtype='object')

# %%
# df = df.drop(['Country','Status', "AdultMortality", 'infantdeaths'], axis=1)

# %%
df = df0[['Alcohol', 'HepatitisB', 'Measles', 'BMI', 'Polio', 'HIV/AIDS', 'Lifeexpectancy']]

# Display the new DataFrame
df.head()
# Out:
#    Alcohol  HepatitisB  Measles   BMI  Polio  HIV/AIDS  Lifeexpectancy
# 0     0.01        65.0     1154  19.1    6.0       0.1            65.0
# 1     0.01        62.0      492  18.6   58.0       0.1            59.9
# 2     0.01        64.0      430  18.1   62.0       0.1            59.9
# 3     0.01        67.0     2787  17.6   67.0       0.1            59.5
# 4     0.01        68.0     3013  17.2   68.0       0.1            59.2

# %% [markdown]
# ### Checking for missing values presents in Columns

# %%
total_missing_values = 0
for col in df.columns:
    missing_values = df[col].isnull().sum()
    total_missing_values += missing_values
    print(f'Missing values on {col} is {missing_values}.')
print(f'Total Missing values {total_missing_values}.')
# Out:
# Missing values on Alcohol is 194.
# Missing values on HepatitisB is 553.
# Missing values on Measles is 0.
# Missing values on BMI is 34.
# Missing values on Polio is 19.
# Missing values on HIV/AIDS is 0.
# Missing values on Lifeexpectancy is 10.
# Total Missing values 810.

# %% [markdown]
# ### Filling the missing or null values with the values of previous column using method <span style="color:green">ffill<span>

# %%
total_missing_values = 0
for col in df.columns:
    missing_values = df[col].isnull().sum()
    if missing_values > 0:
        df[col].fillna(method='ffill', inplace=True)  # Use inplace=True to modify the DataFrame in place
    total_missing_values += missing_values
    print(f'Missing values in {col} is {missing_values}.')
print(f'Total Missing values: {total_missing_values}.')
# Out:
# Missing values in Alcohol is 194.
# Missing values in HepatitisB is 553.
# Missing values in Measles is 0.
# Missing values in BMI is 34.
# Missing values in Polio is 19.
# Missing values in HIV/AIDS is 0.
# Missing values in Lifeexpectancy is 10.
# Total Missing values: 810.
# C:\Users\Saurav Karki\AppData\Local\Temp\ipykernel_11532\1742208566.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(method='ffill', inplace=True)  # Use inplace=True to modify the DataFrame in place
# ...

# %% [markdown]
# ## <p style="color:orange">Data Visulization </p>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Alcohol', 'HepatitisB', 'Measles', 'BMI', 'Polio', 'HIV/AIDS',
#        'Lifeexpectancy'],
#       dtype='object')

# %%
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
df.boxplot(figsize=(10, 8))
# plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.pairplot(df)
plt.show()

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
df['Lifeexpectancy'].plot(kind='density')
plt.xlabel('Lifeexpectancy')
plt.show()

# %%
df.head()
# Out:
#    Alcohol  HepatitisB  Measles   BMI  Polio  HIV/AIDS  Lifeexpectancy
# 0     0.01        65.0     1154  19.1    6.0       0.1            65.0
# 1     0.01        62.0      492  18.6   58.0       0.1            59.9
# 2     0.01        64.0      430  18.1   62.0       0.1            59.9
# 3     0.01        67.0     2787  17.6   67.0       0.1            59.5
# 4     0.01        68.0     3013  17.2   68.0       0.1            59.2

# %% [markdown]
# ### From heatmap the relations of <span style='color:red'>Measleas </span>  and<span style='color:red'>HIV/AIDS </span>  is low with<span style='color:green'> Lifeexpectancy </span> so droping them

# %%
df.drop(['Measles', 'HIV/AIDS', 'Alcohol'], axis=1, inplace=True)
# Out:
# C:\Users\Saurav Karki\AppData\Local\Temp\ipykernel_11532\3107160562.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Measles', 'HIV/AIDS', 'Alcohol'], axis=1, inplace=True)

# %%
sns.pairplot(df)

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# ## Using <span style='color:green'>Sklearn</span> <span style='color:yellow'>Ordinary Least Squares (OLS) </span>

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
X = df.iloc[: , :-1]
y = df.iloc[: , 1]

# %%
print(X.shape)
print(y.shape)
# Out:
# (2938, 3)
# (2938,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (2350, 3)
# (2350,)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
df.head()
# Out:
#    HepatitisB   BMI  Polio  Lifeexpectancy
# 0        65.0  19.1    6.0            65.0
# 1        62.0  18.6   58.0            59.9
# 2        64.0  18.1   62.0            59.9
# 3        67.0  17.6   67.0            59.5
# 4        68.0  17.2   68.0            59.2

# %%
y_pred = lr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 7.323694756859884e-29

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [-2.91401372e-17  1.00000000e+00 -3.33066907e-16]
# 2.842170943040401e-14

# %% [markdown]
# ## Using <span style='color:green'>Sklearn</span> <span style='color:yellow'>Stochastic Gradient Descent </span>

# %%
from sklearn.linear_model import SGDRegressor

# %%
sgdr = SGDRegressor(max_iter=100, learning_rate='constant', eta0=0.01)  #learning_rate = constant || 0.1"

# %%
sgdr.fit(X_train,y_train)
# Out:
# SGDRegressor(learning_rate='constant', max_iter=100)

# %%
y_pred = sgdr.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# -4.524712924864701e+25
